# %%
import math
import json
import traceback

import requests
from bs4 import BeautifulSoup

from stem import Signal
from stem.control import Controller

from fake_useragent import UserAgent

import pandas as pd

from tqdm.notebook import tqdm

from selenium import webdriver

# %%
def create_driver():
    options = webdriver.ChromeOptions()
    proxy = 'localhost:9050'   
    options.add_argument('--proxy-server=socks5://' + proxy)
    options.add_argument('--headless')
    driver = webdriver.Chrome(options=options)
    
    return driver

def close_driver(driver):
    driver.quit()

def get_request(url, with_driver=False, driver=None):
    
    renew_tor_ip()
    
    user_agent = UserAgent().chrome
    headers = {'User-Agent': user_agent}

    try:
        if with_driver:
            if not driver:
                driver = create_driver()
                driver.get(url)
                r = driver.page_source
                close_driver(driver)
            else:
                driver.get(url)
                r = driver.page_source
        else:
            session = requests.session()
            session.proxies = {}
            session.proxies['http']='socks5h://localhost:9050'
            session.proxies['https']='socks5h://localhost:9050'
            r = session.get(url, headers=headers).text
    except Exception as e:
        print(str(e))
    else:
        return r   

def get_current_ip():
    session = requests.session()

    # TO Request URL with SOCKS over TOR
    session.proxies = {}
    session.proxies['http']='socks5h://localhost:9050'
    session.proxies['https']='socks5h://localhost:9050'

    try:
        r = session.get('http://httpbin.org/ip')
    except Exception as e:
        print(str(e))
    else:
        return r.text.split()[2].replace('\"', '')


def renew_tor_ip():
    with Controller.from_port(port = 9051) as controller:
        controller.authenticate(password="tor_for_parsing")
        controller.signal(Signal.NEWNYM)

# %%
with open('volk_polo_pages.json', 'r') as file:
    cars_pages = json.load(file)

# %%
len(cars_pages), len(set(cars_pages))
# Out:
# (887, 886)

# %%
cars_pages = list(set(cars_pages))

# %%
def _get_car_info(page, url):


    features_dict = dict()
    
#     car_brand = url.split('/')[-4]
#     car_model = url.split('/')[-3]
    
#     features_dict.update({'brand': car_brand, 'model': car_model})

    new_or_used = url.split('/')[4]
    features_dict.update({'new_or_used': new_or_used})
    
    if page.select_one('div[class*=CardSold__title]'):
        print('CAR SOLD')
        return None
    
    info = page.select_one('ul[class*=CardInfo]:not(ul[class*=CardInfoGrouped__list])')
    if info:
        features = info.find_all('li')
        for feature in features:
            spans = feature.find_all('span')
            feature_name = spans[0].text.strip().lower().replace('\xa0', '')
            feature_value = spans[1].text.strip().lower().replace('\xa0', '')

            features_dict.update({feature_name: feature_value})
            
    else:
        info = page.select_one('ul[class*=CardInfoGrouped__list]')
        features = info.find_all('li')
        for feature in features:
            feature_div = feature.find_all('div')
            
            name = feature_div[1]
            value = feature_div[0]
                
            feature_name = name.text.strip().lower().replace('\xa0', '')
            feature_value = value.text.strip().lower().replace('\xa0', '').replace(feature_name, '')

            features_dict.update({feature_name: feature_value})
        
    description = page.find('div', {'class': 'CardDescription__textInner'})
    if description:
        description_text = description.get_text(separator=" ").strip().strip().lower().replace('\xa0', '')
    else:
        description_text = ''
        
    features_dict.update({'описание': description_text})
    
    price = page.find('span', {'class': 'OfferPriceCaption__price'}).text.strip().lower().replace('\xa0', '')
    features_dict.update({'цена': price})
    
    
    try:
        benefits = page.find_all('div', {'class': 'CardBenefits__item-title'})
        for benefit in benefits:
            benefit_name = benefit.text.strip().lower().replace('\xa0', '')
            features_dict.update({benefit_name: True})
    except Exception as err:
        # print(repr(err))
        pass
    
    return features_dict

# %%
def get_car_info(car_page, with_driver=False, driver=None):
    resp = get_request(car_page, with_driver=with_driver, driver=driver)
    soup = BeautifulSoup(resp, 'html.parser')
    car_info = _get_car_info(page=soup, url=car_page)
    
    return car_info

def try_to_get_info_5_times(car_page, i, with_driver=True):
    try:
        car_info = None
        if with_driver:
            web_driver = create_driver()
            car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
            web_driver.quit()
        else:
            pass
    except Exception as err:
        print(repr(err))
        print(''.join(traceback.format_tb(err.__traceback__)))
        if i < 1:
            i += 1
            car_info = try_to_get_info_5_times(car_page, i, with_driver=True)
    finally:
        return car_info

# %%
# page = 'https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153536/1102148992-db8a69e3/'
web_driver = create_driver()
page = 'https://auto.ru/cars/used/sale/volkswagen/polo/1101696001-9c15b8b3/'
car_info = try_to_get_info_5_times(page, 0, with_driver=True)
close_driver(web_driver)
print(car_info)
# Out:
# ['https:', '', 'auto.ru', 'cars', 'used', 'sale', 'volkswagen', 'polo', '1101696001-9c15b8b3', '']
# {'год выпуска': '1998', 'пробег': '310000км', 'кузов': 'седан', 'цвет': 'зелёный', 'двигатель': '1.6 л / 100л.с. / бензин', 'налог': '1150₽ / год', 'коробка': 'механическая', 'привод': 'передний', 'руль': 'левый', 'состояние': 'не требует ремонта', 'владельцы': '3 или более', 'птс': 'дубликат', 'таможня': 'растаможен', 'vin': 'wvw**************', 'госномер': '******|71', 'описание': 'продам фольца. сразу о недостатках. надо поменять внутреннюю правую гранату ( на третьей передачи начинается небольшая вибрация при разгоне), расколота передняя правая фара (стекло), есть небольшая дырка в полу не кретичная ( зачищена и обработана пушсалом). в целом кузов на твёрдую 4. оцинкован. датчик топлива не правильно показывает. стоит сигналка с авто запуском, ( но недоходит до стартера, где-то обрыв). по недостаткам всё.     движок не дымит, масло не ест, работает ровно, очень шустрый, 100л.с. передачи не вылетают. задние стёкла затонированны на 90%. штатная музика. передние стеклоподъёмники. арки и днище обработано пушсалом.   мне некогда заниматься, поменял работу и теперь на шести дневке. работы по сути, без фанатизма на два три дня. продаю неспиша. до весны не продам, сниму с продажи. езжу каждый день по 8 км. на работу.  оформлена на меня. красивый номер в подарок (скр71). осаго есть, вам не придется делать страховку при переоформлении.', 'цена': '135000₽'}

# %%
df = pd.DataFrame()

err_pages = 1
counter = 1

for page in tqdm(cars_pages):
    try:
        i = 0
        car_info = try_to_get_info_5_times(page, 0, with_driver=True)
        if car_info:
            df = df.append(car_info, ignore_index=True)
            
            if counter%10 == 0:
                df.to_csv('volk_polo_dataset.csv')
            counter += 1
        else:
            print(f'pages not parsed: {err_pages}')
            print(page)
            err_pages += 1
    except Exception as err:
        print(repr(err))
        print(page)
        continue
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=886.0), HTML(value='')))
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 1
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153111/1102576151-e9bb004d/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 2
# https://auto.ru/cars/used/sale/volkswagen/polo/1102572788-a8605134/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 3
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153111/1102425687-50226634/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 4
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153536/1102217067-5b159c36/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 5
# https://auto.ru/cars/used/sale/volkswagen/polo/1102570745-07a80dd4/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 6
# https://auto.ru/cars/used/sale/volkswagen/polo/1102263843-a07c3c80/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 7
# https://auto.ru/cars/used/sale/volkswagen/polo/1102129059-63ca695b/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 8
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153111/1102369869-63fdf4b1/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 9
# https://auto.ru/cars/used/sale/volkswagen/polo/1071799924-54fd29a3/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 10
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153536/1102382020-9cada44e/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 11
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1102242854-3df182fb/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 12
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153111/1102382019-bc7feff7/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 13
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102472827-ce5657fb/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 14
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102576639-8041fe92/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 15
# https://auto.ru/cars/used/sale/volkswagen/polo/1102280087-43b35b16/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 16
# https://auto.ru/cars/new/group/volkswagen/polo/21802429/22152659/1102384836-f7b82592/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 17
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153111/1102217074-54383db5/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 18
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102344869-043118f6/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 19
# https://auto.ru/cars/used/sale/volkswagen/polo/1102175975-614e8885/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 20
# https://auto.ru/cars/used/sale/volkswagen/polo/1099965574-691853d8/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 21
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1102425681-f2c54d5a/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 22
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153111/1102344954-67d1503d/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 23
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1101988047-748bb454/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 24
# https://auto.ru/cars/used/sale/volkswagen/polo/1102592300-42debc0a/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 25
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153536/1102559154-5c888ef9/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 26
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102491818-bcc387e7/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 27
# https://auto.ru/cars/new/group/volkswagen/polo/21802429/22152659/1101865464-577cec33/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 28
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153536/1102221197-8e070865/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 29
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153536/1102167571-5b9c41c4/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 30
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1102636742-02f51d47/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 31
# https://auto.ru/cars/used/sale/volkswagen/polo/1102505122-bc1c364e/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 32
# https://auto.ru/cars/used/sale/volkswagen/polo/1102490768-f745ba80/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 33
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102559684-bc15ca21/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 34
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153111/1100609554-9f430c73/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 35
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153111/1102302882-fe854dc2/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 36
# https://auto.ru/cars/used/sale/volkswagen/polo/1102583085-b135d797/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 37
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102382050-5ea09bbe/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 38
# https://auto.ru/cars/new/group/volkswagen/polo/21802429/22152659/1102159215-b8c1f125/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 39
# https://auto.ru/cars/used/sale/volkswagen/polo/1102352108-b6e9d5d7/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 40
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102203264-b69b897f/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 41
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102203222-7817bc08/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 42
# https://auto.ru/cars/used/sale/volkswagen/polo/1102571304-3e124906/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 43
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153536/1102521748-ce4b1038/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 44
# https://auto.ru/cars/used/sale/volkswagen/polo/1101435047-078fafe5/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 45
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1102159207-453a8b59/
# AttributeError("'NoneType' object has no attribute 'find_all'")
# ...
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 226
# https://auto.ru/cars/used/sale/volkswagen/polo/1101321897-47635187/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 227
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153536/1102120920-a74611b2/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 228
# https://auto.ru/cars/used/sale/volkswagen/polo/1102074853-713160e1/
# CAR SOLD
# pages not parsed: 229
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102344934-1a448702/?from=listing_all
# CAR SOLD
# pages not parsed: 230
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102382037-5d69dd32/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 231
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153111/1102059319-82962115/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 232
# https://auto.ru/cars/used/sale/volkswagen/polo/1102092066-27e4a4c2/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 233
# https://auto.ru/cars/new/group/volkswagen/polo/21802423/22153111/1102160018-7239ea0b/
# CAR SOLD
# pages not parsed: 234
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102344943-10eb4b6b/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 235
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22152659/1102220038-83db96ec/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 236
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22152659/1102377256-a661e560/?from=listing_all
# CAR SOLD
# pages not parsed: 237
# https://auto.ru/cars/new/group/volkswagen/polo/21802427/22153111/1102344917-4e1bf07e/?from=listing_all
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 238
# https://auto.ru/cars/new/group/volkswagen/polo/21802425/22153536/1102148933-4d1046c0/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 239
# https://auto.ru/cars/used/sale/volkswagen/polo/1102281672-03e62f8d/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 240
# https://auto.ru/cars/used/sale/volkswagen/polo/1098556982-8dcac849/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 241
# https://auto.ru/cars/new/group/volkswagen/polo/21802429/22152659/1102618349-873d6970/
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# AttributeError("'NoneType' object has no attribute 'find_all'")
#   File "<ipython-input-24-3e3bd8e6baf6>", line 13, in try_to_get_info_5_times
#     car_info = get_car_info(car_page, with_driver=with_driver, driver=web_driver)
#   File "<ipython-input-24-3e3bd8e6baf6>", line 4, in get_car_info
#     car_info = _get_car_info(page=soup, url=car_page)
#   File "<ipython-input-23-13ee0c38d40f>", line 30, in _get_car_info
#     features = info.find_all('li')
#
# pages not parsed: 242
# https://auto.ru/cars/used/sale/volkswagen/polo/1102529518-7a11a6f0/

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.to_csv('volk_polo_dataset.csv')
